# %% [markdown]
# # Homework 6: Project Update
#
#
# ### <p style="text-align: right;"> &#9989; Steven VanCamp</p>

# %% [markdown]
# ---
# ## Goals of this assignment
#
# The primary goals of this assignment are to:
#
# * Provide an update on your project progress
# * Submit in-progress Jupyter notebook, slides and LaTeX writeup
#
# ## Assignment instructions
#
# Follow the instructions to complete this assignment.
# Upload the assignment to Gradescope _and_ fill out the homework survey to complete this assignment.
#
# ___
# ### Grading
#
# * Part 1: Project Update (40 points)
# * Part 2: Progress Report (40 points)
#
# **Total:** 60 points

# %% [markdown]
# ------
# ## Part 1: Project Update (30 points)
#
# We will quickly revisit the project proposal from Homework 5 with the same questions listed below.
# If nothing needs to be updated, you can use what you had before.
# If topic or scope of the project has changed, please update accordingly.
# This should match your final submitted project.

# %% [markdown]
# ### 1.0  Your teammate (if applicable)
# Please make sure that you have clear communication and 100% confirmation with another classmate before you put a name here.
#
# If you have a teammate, list the name here:
#
# #### <p style="text-align: right;"> &#9989; Patrick Tutt</p>
#
# and replace "Put your teammate's name here" with the actual name that shown up in Gradescope so that grader can find the file.
# You each will need to submit your own Jupyter notebook to Gradescope.
#
# If you work with another student, you are expected to submit a longer LaTeX writeup.
# You also need to add an appendix documenting on how the work was divided within the team.
# This is to ensure that each individual is contributing to the success of the project.

# %% [markdown]
# <font size=+3>&#9998;</font>

# %% [markdown]
# ### 1.1  Physics question(s) (5 points)
# Record below what are the physics question(s) you want to address in this project?
# 1. Question 1
# 1. Question 2
# 1. ...

# %% [markdown]
# <font size=+3>&#9998;</font>
# 1. Can we model a tuned mass dampner
# 1. Can we model a tuned mass dampner coupled to a building
# 1. Can we use c++ effectively to decrease our computation time
# 1. Can an ode solver such as RK4 be used to complete the simulations

# %% [markdown]
# ###  1.2 Research the topic (5 points)
# You should find out what has been done on the topic before and read a bit of the literature.
# This will give you some idea of what you may expect at the end of the project and also some idea of the complexity of the problems.
# (You don't want a problem that will take longer than the end of the semester to solve.)
# Add links to the references here, and write a short summary of your understanding of each.

# %% [markdown]
# <font size=+3>&#9998;</font>
#
# 1. https://www.sciencedirect.com/science/article/pii/S2352012422000984
#     - This reference gave us an initial idea about how floors are coupled to gether and how a tuned mass dampner affects the overall structure
# 1. Textbook: https://engineering.purdue.edu/~ce573/Documents/Intro%20to%20Structural%20Motion%20Control_Chapter4.pdf
#     - This reference discusses various types of tuned mass dampners and how they are modeled. This also goes into optimization techniques
# 1. Storys: https://onlinelibrary.wiley.com/doi/pdf/10.1002/(SICI)1096-9845(199702)26:2%3C193::AID-EQE634%3E3.0.CO;2-%23
#     - This reference provideds us with a great resource to model a tuned mass dampner as coupled to a building
# 1. Simplified stories: https://onlinelibrary.wiley.com/doi/10.1002/tal.1174
#     - This reference discusses optimization algorithims and techniques for finding the optimal values of tuned mass dampner parameters
# 1. Data: http://www.vibrationdata.com/elcentro.htm
#     - This reference provides us with real data we could use to test out simulation

# %% [markdown]
# ### 1.3  Software help (5 points)
# Identify any pre-existing Python libraries or packages that can be used to aid in answering the question(s).
#
# Record your plan to familiarize yourself with the data/libraries/packages and make sure you're aware of their limitations.

# %% [markdown]
# <font size=+3>&#9998;</font>
# 1. numpy
#     - General array use and math
# 1. scipy
#     - Numerical methods
# 1. matplotlib
#     - visualization tools
# 1. c++
#     - increased computation speed, limited pre-existing libraries
# 1. Data: http://www.vibrationdata.com/elcentro.htm
#     - real world seismic data we could use for our simulations, constrained by observation rate

# %% [markdown]
# ### 1.4 What code will you need to write? (5 points)
# Write your estimation of what additional code will be necessary to run your model or analyze your data.
# If you use data, please identify the sources.
# (If your data is not publicly available, please provide poof that you have been given access to work on the data, such as an email from a research advisor.)

# %% [markdown]
# <font size=+3>&#9998;</font>
# 1. Program describing the system we are simulating (c++)
#     - tuned mass dampner coupled to a building (collection of floors)
#     - coupled mass and springs
# 1. ODE solver (c++)
#     - rk4
# 1. Opimization algorithim (c++)
#     - Point Swarm Optimizer
# 1. Visualization (python)
#     - generate various visuals used for presentations and analysis

# %% [markdown]
# ### 1.5  Difficulties or complications (5 points)
# Think about what difficulties or complications you may run into during your proposed project, and how you plan to overcome them.
# It's always good to have a plan-B result that you can use based on your efforts if you cannot get to the results that you originally planned.

# %% [markdown]
# <font size=+3>&#9998;</font>
# 1. Simulating a large system may be difficult or prone to errors. This is something we'll have to keep in mind and will to be mindfull of when looking at resluts
# 1. Writing most of this in c++ should be fine, but some parts may be slightly difficult due to the lack of native libraries for linear algebra (that we know of)
# 1. We have not dealt with this type of probel before, so our understanding of the problem is limited

# %% [markdown]
# ### 1.6  Relevance to class content (10 points)
# How is your project relevant to what's been taught in this class?

# %% [markdown]
# <font size=+3>&#9998;</font>
# 1. We will be using various techniques and methods to complete our project
#     - ODE solvers
#     - c++
#     - numerical derivatives
#     - FFT
#     - Plotting

# %% [markdown]
# ### 1.7  Acknowledgments (5 points)
# Please add an `x` in the `[ ]` below to acknowledge that you are aware of the template usage for Jupyter notebook, LaTex report template, and presentation guideline (which can be found in the D2L under the "Semester Project". Failure to use the templates will result in 50% reduced points for each category.
# - [x] I have downloaded the Jupyter notebook semester project template and will use the template for the project.
# - [x] I have downloaded the [LaTeX template](https://www.overleaf.com/read/btkjwgpgymnm) into my own (or my teammate's) Overleaf and will write our report using it
# - [x] I will continue working on presentation slides on my own (or with my teammate's) Google account and complete the introduction/method slides, and half of the results
# - [x] I acknowledge that I have NOT submitted a similar project in other classes before

# %% [markdown]
# ---
# # Part 2: Progress Report (40 points)

# %% [markdown]
# ### 2.1 Summary of your progress (20 points)
# Please briefly summarize using bullet points what you've done since the last update.

# %% [markdown]
# <font size=+3>&#9998;</font>
# - We've written a program to simulate and produce results from a system of coupled springs
#     - Includes ODE solver (rk4), and various simple coding techniques
# - We've begun writing a program to simulate a Tuned Mass Dampner coupled to a building (collection of floors)
#     - ODE system is much more complicated and changes with building size so its taking some time to complete
# - We've figured what optimization technique we'll be using
#     -Point Swarm Opitimization

# %% [markdown]
# ### 2.2 List what remains to be done and a timeline to complete it (20 points)

# %% [markdown]
# <font size=+3>&#9998;</font>
# - Finishing the program to simulate a Tuned Mass Dampner coupled to a building (collection of floors)
#     - This should be finished this coming week (Apr 17-21)
# - Begin writing the opimization algorithim (PSO) neccesary to obtain the optimal TMD parameters
#     - This should be finished this coming week (Apr 17-21)
# - Run simulations and obtain results for various scenarios
#     - This should be finished this coming weekend (Apr 22-23)
# - Write report (overleaf)
#     - This should be finished by next week (Apr 24-28)
# - Finish slides
#     - This should be finished by this coming weekend (Apr 22-23)

# %% [markdown]
# ---
# ## Assignment Wrap-up
#
# To complete this assignement, you need to
# 1. Submit this homework Jupyter notebook
# 2. Submit your current semester-project Jupyter notebook
# 3. Submit your current Overleaf report
# 4. Submit your current slides
#
# **COMPLETE the homework survey through the cell below or through [this link](https://forms.gle/UFKsNXYAxUss3HZG8)**

# %%
from IPython.display import HTML
HTML(
"""
<iframe 
	src="https://forms.gle/UFKsNXYAxUss3HZG8" 
	width="80%" 
	height="1200px" 
	frameborder="0" 
	marginheight="0" 
	marginwidth="0">
	Loading...
</iframe>
"""
)
# Out:
# <iframe
# 	src="https://forms.gle/UFKsNXYAxUss3HZG8"
# 	width="80%"
# 	height="1200px"
# 	frameborder="0"
# 	marginheight="0"
# 	marginwidth="0">
# 	Loading...
# </iframe>

# %% [markdown]
# ---
#
# ### Congratulations, you're done!
#
# Submit this assignment by uploading it to the course Gradescope web page.
# Find the submission folder link for Homework #6, and upload the file in .ipynb format there.
